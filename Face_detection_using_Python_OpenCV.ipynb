# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavyabhagerathi/Code-Clause-AI-projects/blob/main/Face_detection_using_Python_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **OpenCV for Face Detection in Images**

# %% [markdown]
# Step 1: Import the OpenCV Package

# %%
import cv2
imagePath = 'group_photo2.jpg'

# %% [markdown]
# Step 2: Read the Image

# %%
img = cv2.imread(imagePath)

# %%
img.shape
# Out:
# (339, 509, 3)

# %% [markdown]
# Step 3: Convert the Image to Grayscale

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
gray_image.shape
# Out:
# (339, 509)

# %% [markdown]
# Step 4: Load the Classifier

# %%
face_classifier = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# %% [markdown]
# Step 5: Perform the Face Detection

# %%
face = face_classifier.detectMultiScale(
    gray_image, scaleFactor=1.1, minNeighbors=5, minSize=(40, 40)
)

# %% [markdown]
# Step 6: Drawing a Bounding Box

# %%
for (x, y, w, h) in face:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 4)

# %% [markdown]
# Step 7: Displaying the Image

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.imshow(img_rgb)
plt.axis('off')
# Out:
# (-0.5, 508.5, 338.5, -0.5)
